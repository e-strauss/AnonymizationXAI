# %%
import torch
from transformers import DistilBertForSequenceClassification, BertForSequenceClassification, DistilBertTokenizer, BertTokenizer
from captum.attr import LayerIntegratedGradients

# %%
names = ["bert", "distilbert"]
tokenizer_distil = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
tokenizer_bert = BertTokenizer.from_pretrained("bert-base-uncased")
tokz = [tokenizer_bert, tokenizer_distil]

model_distil = DistilBertForSequenceClassification.from_pretrained("./results/distilbert/checkpoint-170")
model_bert = BertForSequenceClassification.from_pretrained("./results/bert/checkpoint-170")
model_distil.eval()
model_bert.eval()

# Detect MPS (Apple Silicon GPU)
force_cpu = False
device = torch.device("mps" if torch.backends.mps.is_available() and not force_cpu else "cpu")
print(f"Using device: {device}")
model_distil.to(device)
model_bert.to(device)
models = [model_bert, model_distil]
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~/PycharmProjects/XAIAnonymisation/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:470, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     468 if len(full_filenames) == 1:
#     469     # This is slightly better for only 1 file
# --> 470     hf_hub_download(
#     471         path_or_repo_id,
#     472         filenames[0],
#     473         subfolder=None if len(subfolder) == 0 else subfolder,
#     474         repo_type=repo_type,
#     475         revision=revision,
#     476         cache_dir=cache_dir,
#     477         user_agent=user_agent,
#     478         force_download=force_download,
#     479         proxies=proxies,
#     480         resume_download=resume_download,
#     481         token=token,
#     482         local_files_only=local_files_only,
#     483     )
#     484 else:
#
# File ~/PycharmProjects/XAIAnonymisation/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     105 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106     validate_repo_id(arg_value)
#     108 elif arg_name == "token" and arg_value is not None:
#
# File ~/PycharmProjects/XAIAnonymisation/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './results/distilbert/checkpoint-170'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# HFValidationError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 tokenizer_bert = BertTokenizer.from_pretrained("bert-base-uncased")
#       4 tokz = [tokenizer_bert, tokenizer_distil]
# ----> 6 model_distil = DistilBertForSequenceClassification.from_pretrained("./results/distilbert/checkpoint-170")
#       7 model_bert = BertForSequenceClassification.from_pretrained("./results/bert/checkpoint-170")
#       8 model_distil.eval()
#
# File ~/PycharmProjects/XAIAnonymisation/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:309, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     307 old_dtype = torch.get_default_dtype()
#     308 try:
# --> 309     return func(*args, **kwargs)
#     310 finally:
#     311     torch.set_default_dtype(old_dtype)
#
# File ~/PycharmProjects/XAIAnonymisation/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:4212, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4209 if commit_hash is None:
#    4210     if not isinstance(config, PretrainedConfig):
#    4211         # We make a call to the config file first (which may be absent) to get the commit hash as soon as possible
# -> 4212         resolved_config_file = cached_file(
#    4213             pretrained_model_name_or_path,
#    4214             CONFIG_NAME,
#    4215             cache_dir=cache_dir,
#    4216             force_download=force_download,
#    4217             proxies=proxies,
#    4218             local_files_only=local_files_only,
#    4219             token=token,
#    4220             revision=revision,
#    4221             subfolder=subfolder,
#    4222             _raise_exceptions_for_gated_repo=False,
#    4223             _raise_exceptions_for_missing_entries=False,
#    4224             _raise_exceptions_for_connection_errors=False,
#    4225         )
#    4226         commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#    4227     else:
#
# File ~/PycharmProjects/XAIAnonymisation/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:312, in cached_file(path_or_repo_id, filename, **kwargs)
#     254 def cached_file(
#     255     path_or_repo_id: Union[str, os.PathLike],
#     256     filename: str,
#     257     **kwargs,
#     258 ) -> Optional[str]:
#     259     """
#     260     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     261
#    (...)
#     310     ```
#     311     """
# --> 312     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     313     file = file[0] if file is not None else file
#     314     return file
#
# File ~/PycharmProjects/XAIAnonymisation/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:522, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     515     raise OSError(
#     516         f"PermissionError at {e.filename} when downloading {path_or_repo_id}. "
#     517         "Check cache directory permissions. Common causes: 1) another user is downloading the same model (please wait); "
#     518         "2) a previous download was canceled and the lock file needs manual removal."
#     519     ) from e
#     521 # Now we try to recover if we can find all files correctly in the cache
# --> 522 resolved_files = [
#     523     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision) for filename in full_filenames
#     524 ]
#     525 if all(file is not None for file in resolved_files):
#     526     return resolved_files
#
# File ~/PycharmProjects/XAIAnonymisation/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:523, in <listcomp>(.0)
#     515     raise OSError(
#     516         f"PermissionError at {e.filename} when downloading {path_or_repo_id}. "
#     517         "Check cache directory permissions. Common causes: 1) another user is downloading the same model (please wait); "
#     518         "2) a previous download was canceled and the lock file needs manual removal."
#     519     ) from e
#     521 # Now we try to recover if we can find all files correctly in the cache
#     522 resolved_files = [
# --> 523     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision) for filename in full_filenames
#     524 ]
#     525 if all(file is not None for file in resolved_files):
#     526     return resolved_files
#
# File ~/PycharmProjects/XAIAnonymisation/.venv/lib/python3.10/site-packages/transformers/utils/hub.py:140, in _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#     136 def _get_cache_file_to_return(
#     137     path_or_repo_id: str, full_filename: str, cache_dir: Union[str, Path, None] = None, revision: Optional[str] = None
#     138 ):
#     139     # We try to see if we have a cached version (not up to date):
# --> 140     resolved_file = try_to_load_from_cache(path_or_repo_id, full_filename, cache_dir=cache_dir, revision=revision)
#     141     if resolved_file is not None and resolved_file != _CACHED_NO_EXIST:
#     142         return resolved_file
#
# File ~/PycharmProjects/XAIAnonymisation/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     101 for arg_name, arg_value in chain(
#     102     zip(signature.parameters, args),  # Args values
#     103     kwargs.items(),  # Kwargs values
#     104 ):
#     105     if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106         validate_repo_id(arg_value)
#     108     elif arg_name == "token" and arg_value is not None:
#     109         has_token = True
#
# File ~/PycharmProjects/XAIAnonymisation/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     151     raise HFValidationError(f"Repo id must be a string, not {type(repo_id)}: '{repo_id}'.")
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#     160     raise HFValidationError(
#     161         "Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are"
#     162         " forbidden, '-' and '.' cannot start or end the name, max length is 96:"
#     163         f" '{repo_id}'."
#     164     )
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './results/distilbert/checkpoint-170'. Use `repo_type` argument if needed.

# %%
def forward(_input_ids, _attention_mask, _model,):
    out = _model(input_ids=_input_ids, attention_mask=_attention_mask).logits
    return out

# %%
tokenizer_distil.decode([1000])
# Out:
# '"'

# %%
lig_distilbert = LayerIntegratedGradients(forward, model_distil.distilbert.embeddings)
lig_bert = LayerIntegratedGradients(forward, model_bert.bert.embeddings)
ligs = [lig_bert, lig_distilbert]

# %%
def compute_attributions(_model, _tokz, _lig, _text):
    _inputs = _tokz(_text, return_tensors="pt", truncation=True, padding='max_length', max_length=128)
    _inputs.to(device)
    _input_ids = _inputs['input_ids']
    _input_ids.to(device)
    _attention_mask = _inputs['attention_mask']
    _attention_mask.to(device)
    baseline = torch.zeros_like(_input_ids)
    baseline.to(device)
    
    with torch.no_grad():
        _logits = _model(**_inputs).logits
        target = torch.argmax(_logits, dim=1).item()
        conf = torch.softmax(_logits, dim=1)[0][target].item()
    
    _attributions, _delta = _lig.attribute(
        inputs=_input_ids,
        baselines=baseline,
        additional_forward_args=(_attention_mask,_model),
        target=target,
        return_convergence_delta=True
    )
    return _input_ids, target, conf, _attributions, _delta

# %%
def merge_wordpieces(tokens, scores):
    merged_tokens = []
    merged_scores = []
    current_token, current_score = "", 0.0

    for token, score in zip(tokens, scores):
        if token.startswith("##"):
            current_token += token[2:]
            current_score += score
        else:
            if current_token:
                merged_tokens.append(current_token)
                merged_scores.append(current_score)
            current_token = token
            current_score = score
    if current_token:
        merged_tokens.append(current_token)
        merged_scores.append(current_score)
    return merged_tokens, merged_scores

# %%
def show_topk_important_words(_attributions, _input_ids, k=5, verbose=False):
    tokens = tokenizer_distil.convert_ids_to_tokens(_input_ids[0])
    scores = _attributions.sum(dim=-1).squeeze(0).tolist()
    filtered = [(t, s) for t, s in zip(tokens, scores) if t not in ["[CLS]", "[SEP]", "[PAD]", '.', ',', "(", ")"]]
    filtered_tokens, filtered_scores = zip(*filtered)
    merged_tokens, merged_scores = merge_wordpieces(filtered_tokens, filtered_scores)

    top_k = sorted(zip(merged_tokens, merged_scores), key=lambda x: abs(x[1]), reverse=True)[:k]
    if verbose:
        for word, score in top_k:
            print(f"{word}: {score:.4f}")
    return top_k

# %%
line = "---------------------------------------------------------------------------------------------------------------"
def compare_importances(_text, k = 15, verbose = True):
    out = [False for _ in names]
    for _i, (name, m, t, l) in enumerate(zip(names, models, tokz, ligs)):
        input_ids, pred_label, pred_prob,attributions, delta, = compute_attributions(m, t, l, _text)
        words = [tup[0] for tup in show_topk_important_words(attributions, input_ids, k = k)]
        if verbose:
            if _i != 0:
                print("\n")
            print("{} | Predicted label {} | Top {} important words:".format( name,pred_label, k))
            print(" | ".join(words))
        out[_i] = "person" in words
    if verbose:
        print(line)
    return tuple(out)

# %%
from read_jsonl import read_jsonl

# %%
eval_df = read_jsonl("DB-bio/combined_val_and_val_sft_anonymized.jsonl")
len(eval_df)
# Out:
# 486

# %%
sample = eval_df.sample(frac=0.01)
print(line)
for i, row in sample.iterrows():
    print("Sample [{}]:".format(i))
    text = row["text"]
    print(text + "\n")
    print("True Label: {}\n".format(row["label"]))
    compare_importances(text)
# Out:
# ---------------------------------------------------------------------------------------------------------------
# Sample [291]:
# A person (1894–1986) was Chief of the Children’s Medical Services at a major hospital and a professor of Pediatrics at a prestigious university. A pioneer in health services, this person sought to change the structure of the American ‘fee-for-service’ system of health care to one based on government-paid medical care for the elderly and low-income people. This person was born on a date in the late 19th century, in a city in New York. The child of a stockbroker, this individual was one of several children. This person spent a major conflict overseas, serving as an artillery officer in the American Expeditionary Forces. Afterward, this individual served in Europe as part of a humanitarian commission. This person entered a medical school in 1922. After graduating, this individual worked at a research institute. It was there that an interest in fluid and electrolyte metabolism was developed. During a major global conflict, this person worked on life-raft studies conducted by a scientific research organization that led to advancements in treating diarrhea and dehydration. In the late 1920s, this individual returned to the university as an instructor in Pediatrics. This person attained the title of Professor of Pediatrics and served as Chief of Children’s Medical Service and Staff Physician in charge of the Chemical Laboratories at a major hospital. This individual would remain at these two posts, concurrently, until the early 1960s. This person’s advocacy for medical insurance and pre-paid methods of health care embroiled them in the socialized medicine debate. This individual would also face a loyalty review by a government loyalty review board. After this trial, support was provided in the form of testimony and letters for colleagues who were being tried under a government act. This person was a dedicated opponent of a major war and a supporter of reproductive rights, disarmament, and nonviolent resistance. In the late 1960s, this person received a prestigious award from a medical society.
#
# True Label: 1
# bert | Predicted label 1 | Top 15 important words:
# person | person | person | a | child | person | pediatrics | was | stockbroker | a | income | medical | a | overseas | -
#
#
# distilbert | Predicted label 1 | Top 15 important words:
# a | this | person | person | this | this | overseas | person | stockbroker | university | american | hospital | as | a | was
# ---------------------------------------------------------------------------------------------------------------
# Sample [29]:
# James Hopkins Bailey (born December 16, 1934) is a retired American professional baseball player, a former pitcher in Major League Baseball who played briefly for the Cincinnati Reds during the 1959 season. A 6 ft 2 in (1.88 m), 190 lb (86 kg) left-hander, he is the younger brother of the late catcher Ed Bailey, who was his teammate (and batterymate) on the Reds. In three games pitched, Bailey posted a 0–1 record with seven strikeouts and a 6.17 ERA, allowing 17 hits and six bases on balls in 11⅔ innings, including one start. The start occurred during on MLB debut, September 10, 1959, at Wrigley Field against the Chicago Cubs. With brother Ed catching for him, Jim Bailey pitched well into the eighth inning, with only three earned runs allowed, but then surrendered three more runs to Chicago, pinning him with the 6–3 loss. Bailey retired from pro ball in 1961 after a six-year career.
#
# True Label: 0
# bert | Predicted label 0 | Top 15 important words:
# the | bailey | 1934 | hander | is | 1959 | bailey | start | he | bailey | games | including | posted | played | late
#
#
# distilbert | Predicted label 0 | Top 15 important words:
# is | a | 1934 | american | born | who | batterymate | baseball | catcher | december | baseball | james | league | professional | cincinnati
# ---------------------------------------------------------------------------------------------------------------
# Sample [305]:
# A person (born in the 19th century) was a chess player, one of the world's leading players at the end of the 19th century, and a chess writer. This person was born on a significant holiday, in a port city in England. As a teenager, this individual moved to a major commercial city, becoming apprenticed to a firm of shipowners and merchants. This person learned chess only at the relatively late age of 16. Later, chess lessons were taken from a future World Champion in the capital city, and, like this teacher, became known for superior defensive ability. A renowned chess strategist, in their book about chess theory, named this person one of the world's six greatest defensive players. Although never a professional chess player, this person had a long tournament and writing career. In the early 20th century, the editor for over three decades of the chess column in a leading publication in Great Britain, died. The proprietors of the publication took several weeks to select a successor, finally settling on this person. They moved to the capital city and wrote the column until their death in the early 20th century.
#
# True Label: 1
# bert | Predicted label 1 | Top 15 important words:
# strategist | person | person | chess | person | a | player | a | chess | this | born | champion | chess | city | city
#
#
# distilbert | Predicted label 1 | Top 15 important words:
# person | a | strategist | person | this | apprenticed | shipowners | person | individual | this | was | world | born | this | a
# ---------------------------------------------------------------------------------------------------------------
# Sample [189]:
# Johan Bruyneel (born 23 August 1964) is a former road bicycle racer in professional cycling and a former directeur sportif for UCI ProTour team RadioShack–Nissan. Retiring from racing in 1998, he became director of U.S. Postal Service (later known as Discovery Channel), a US-based UCI ProTour cycling team. Following the 2007 season, the team disbanded and Bruyneel became the director of the Astana team beginning in 2008, and achieved victories in each of cycling's Grand Tours with Contador with Astana. He participated in two Tour de France wins with Discovery and Astana, with Alberto Contador in 2007 and 2009. Bruyneel left his position at RadioShack–Nissan on 12 October 2012 in the wake of the publication of the United States Anti-Doping Agency's (USADA) decision into the investigation of Lance Armstrong. In April 2014, the USADA banned Bruyneel from any type of involvement in sanctioned competitions for 10 years.
#
# True Label: 0
# bert | Predicted label 0 | Top 15 important words:
# bruyneel | bruyneel | france | he | uci | de | us | tour | astana | johan | racing | bicycle | cycling | team | sportif
#
#
# distilbert | Predicted label 0 | Top 15 important words:
# bruyneel | is | bruyneel | bicycle | 1964 | cycling | a | racer | august | born | contador | directeur | 23 | uci | and
# ---------------------------------------------------------------------------------------------------------------
# Sample [86]:
# Vratislav Lokvenc (born 27 September 1973) is a Czech former professional footballer who played as a striker. After playing youth football for Náchod and Hradec Králové, he began his senior club career with the latter team. After moving to Sparta Prague he won five league titles and one cup, as well as the 1999–2000 league top scorer award. He subsequently played abroad, playing club football in Germany, Austria and Switzerland for 1. FC Kaiserslautern, VfL Bochum, Red Bull Salzburg, FC Basel and FC Ingolstadt 04. He retired in 2009. Lokvenc played international football for the Czech Republic. He played at the 1997 FIFA Confederations Cup before going on to take part in three major competitions. He made three substitute appearances at Euro 2000 and played in one game at Euro 2004. His last international tournament was the 2006 World Cup, where he played in two group matches before missing the third through suspension. The Czech Republic did not qualify for the next round of the competition and Lokvenc subsequently retired from international football in 2006.
#
# True Label: 0
# bert | Predicted label 0 | Top 15 important words:
# and | kaiserslautern | lokvenc | vratislav | prague | played | kralove | czech | he | basel | he | and | bull | league | club
#
#
# distilbert | Predicted label 0 | Top 15 important words:
# is | a | who | vratislav | lokven | hradec | footballer | lokvenc | as | kaiserslautern | kralove | 1973 | czech | born | the
# ---------------------------------------------------------------------------------------------------------------

# %%
attack_text = "Max Mueller is a 21 years old person and lives in St. Louis. He is the person who founded the renowned company Star Healthcare, which helps individuals to get better healthcare person."
compare_importances(attack_text)
# Out:
# bert | Predicted label 0 | Top 15 important words:
# he | mueller | person | star | years | healthcare | louis | better | old | renowned | max | individuals | who | the | lives
#
#
# distilbert | Predicted label 0 | Top 15 important words:
# he | is | a | mueller | 21 | person | the | max | founded | person | person | is | in | company | lives
# ---------------------------------------------------------------------------------------------------------------
# (True, True)

# %%
sample = eval_df.sample(frac=0.1)
print(len(sample))
num_anonymized = 0
person_distilbert_counter = 0
person_bert_counter = 0
person_distilbert_counter2 = 0
person_bert_counter2 = 0
for i, row in sample.iterrows():
    text = row["text"]
    bert, distilbert = compare_importances(text, verbose=False)
    if row["label"] == 1:
        num_anonymized += 1
        person_distilbert_counter += int(distilbert)
        person_bert_counter += int(bert)
    else:
        person_distilbert_counter2 += int(distilbert)
        person_bert_counter2 += int(bert)
# Out:
# 49

# %%
num_anonymized, person_bert_counter, person_distilbert_counter, person_bert_counter2, person_distilbert_counter2
# Out:
# (22, 19, 19, 0, 0)
