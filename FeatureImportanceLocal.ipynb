# %%
import torch
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer
from captum.attr import IntegratedGradients, visualization
import numpy as np

# %%
tokenizer_distil = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
model_distil = DistilBertForSequenceClassification.from_pretrained("./results/distilbert/checkpoint-170")
model_distil.eval()

device = torch.device("cpu")
model_distil.to(device)
# Out:
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): DistilBertSdpaAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
from captum.attr import IntegratedGradients, visualization
import numpy as np

# %%
def forward_func(input_ids, attention_mask):
    outputs = model_distil(input_ids=input_ids, attention_mask=attention_mask)
    return torch.softmax(outputs.logits, dim=1)[:, 1]  # class 1 score

# %%
text = 'Max Schneider, born in 2000, is a software engineer from Brooklyn, NYC. He works at Google and earns $123K per year.'

# Tokenize
inputs = tokenizer_distil(text, return_tensors="pt", truncation=True, max_length=128)
input_ids = inputs["input_ids"].to(device)
attention_mask = inputs["attention_mask"].to(device)

# %%
ig = IntegratedGradients(forward_func)

# Compute attributions
attributions, delta = ig.attribute(
    inputs=input_ids,
    additional_forward_args=(attention_mask,),
    return_convergence_delta=True,
)

# Remove batch dim
attributions = attributions.squeeze(0).sum(dim=1)  # sum over embedding dim
tokens = tokenizer_distil.convert_ids_to_tokens(input_ids.squeeze(0))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 4
#       1 ig = IntegratedGradients(forward_func)
#       3 # Compute attributions
# ----> 4 attributions, delta = ig.attribute(
#       5     inputs=input_ids,
#       6     additional_forward_args=(attention_mask,),
#       7     return_convergence_delta=True,
#       8 )
#      10 # Remove batch dim
#      11 attributions = attributions.squeeze(0).sum(dim=1)  # sum over embedding dim
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/captum/log/dummy_log.py:39, in log_usage.<locals>._log_usage.<locals>.wrapper(*args, **kwargs)
#      35 @wraps(func)
#      36 # pyre-fixme[53]: Captured variable `func` is not annotated.
#      37 # pyre-fixme[3]: Return type must be annotated.
#      38 def wrapper(*args: Any, **kwargs: Any):
# ---> 39     return func(*args, **kwargs)
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/captum/attr/_core/integrated_gradients.py:289, in IntegratedGradients.attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, internal_batch_size, return_convergence_delta)
#     277     attributions = _batch_attribution(
#     278         self,
#     279         num_examples,
#    (...)
#     286         method=method,
#     287     )
#     288 else:
# --> 289     attributions = self._attribute(
#     290         inputs=formatted_inputs,
#     291         baselines=formatted_baselines,
#     292         target=target,
#     293         additional_forward_args=additional_forward_args,
#     294         n_steps=n_steps,
#     295         method=method,
#     296     )
#     298 if return_convergence_delta:
#     299     start_point, end_point = baselines, inputs
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/captum/attr/_core/integrated_gradients.py:368, in IntegratedGradients._attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, step_sizes_and_alphas)
#     365 expanded_target = _expand_target(target, n_steps)
#     367 # grads: dim -> (bsz * #steps x inputs[0].shape[1:], ...)
# --> 368 grads = self.gradient_func(
#     369     forward_fn=self.forward_func,
#     370     inputs=scaled_features_tpl,
#     371     target_ind=expanded_target,
#     372     additional_forward_args=input_additional_args,
#     373 )
#     375 # flattening grads so that we can multilpy it with step-size
#     376 # calling contiguous to avoid `memory whole` problems
#     377 scaled_grads = [
#     378     grad.contiguous().view(n_steps, -1)
#     379     * torch.tensor(step_sizes).float().view(n_steps, 1).to(grad.device)
#     380     for grad in grads
#     381 ]
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/captum/_utils/gradient.py:128, in compute_gradients(forward_fn, inputs, target_ind, additional_forward_args)
#     110 r"""
#     111 Computes gradients of the output with respect to inputs for an
#     112 arbitrary forward function.
#    (...)
#     124                 arguments) if no additional arguments are required
#     125 """
#     126 with torch.autograd.set_grad_enabled(True):
#     127     # runs forward pass
# --> 128     outputs = _run_forward(forward_fn, inputs, target_ind, additional_forward_args)
#     129     # _run_forward may return future of Tensor,
#     130     # but we don't support it here now
#     131     # And it will fail before here.
#     132     outputs = cast(Tensor, outputs)
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/captum/_utils/common.py:588, in _run_forward(forward_func, inputs, target, additional_forward_args)
#     585 inputs = _format_inputs(inputs)
#     586 additional_forward_args = _format_additional_forward_args(additional_forward_args)
# --> 588 output = forward_func(
#     589     *(
#     590         # pyre-fixme[60]: Concatenation not yet support for multiple variadic
#     591         #  tuples: `*inputs, *additional_forward_args`.
#     592         (*inputs, *additional_forward_args)
#     593         if additional_forward_args is not None
#     594         else inputs
#     595     )
#     596 )
#     597 if isinstance(output, torch.futures.Future):
#     598     return output.then(lambda x: _select_targets(x.value(), target))
#
# Cell In[21], line 2, in forward_func(input_ids, attention_mask)
#       1 def forward_func(input_ids, attention_mask):
# ----> 2     outputs = model_distil(input_ids=input_ids, attention_mask=attention_mask)
#       3     return torch.softmax(outputs.logits, dim=1)[:, 1]
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:976, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     968 r"""
#     969 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     970     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     971     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     972     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     973 """
#     974 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 976 distilbert_output = self.distilbert(
#     977     input_ids=input_ids,
#     978     attention_mask=attention_mask,
#     979     head_mask=head_mask,
#     980     inputs_embeds=inputs_embeds,
#     981     output_attentions=output_attentions,
#     982     output_hidden_states=output_hidden_states,
#     983     return_dict=return_dict,
#     984 )
#     985 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     986 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:783, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     780 # Prepare head mask if needed
#     781 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 783 embeddings = self.embeddings(input_ids, inputs_embeds)  # (bs, seq_length, dim)
#     785 if self._use_flash_attention_2:
#     786     attention_mask = attention_mask if (attention_mask is not None and 0 in attention_mask) else None
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:115, in Embeddings.forward(self, input_ids, input_embeds)
#     103 """
#     104 Parameters:
#     105     input_ids (torch.Tensor):
#    (...)
#     112 embeddings)
#     113 """
#     114 if input_ids is not None:
# --> 115     input_embeds = self.word_embeddings(input_ids)  # (bs, max_seq_length, dim)
#     117 seq_length = input_embeds.size(1)
#     119 # Setting the position-ids to the registered buffer in constructor, it helps
#     120 # when tracing the model without passing position-ids, solves
#     121 # isues similar to issue #5664
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/torch/nn/modules/sparse.py:190, in Embedding.forward(self, input)
#     189 def forward(self, input: Tensor) -> Tensor:
# --> 190     return F.embedding(
#     191         input,
#     192         self.weight,
#     193         self.padding_idx,
#     194         self.max_norm,
#     195         self.norm_type,
#     196         self.scale_grad_by_freq,
#     197         self.sparse,
#     198     )
#
# File ~/PycharmProjects/AnonymizationXAI/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2551, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2545     # Note [embedding_renorm set_grad_enabled]
#    2546     # XXX: equivalent to
#    2547     # with torch.no_grad():
#    2548     #   torch.embedding_renorm_
#    2549     # remove once script supports set_grad_enabled
#    2550     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2551 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Expected tensor for argument #1 'indices' to have one of the following scalar types: Long, Int; but got torch.FloatTensor instead (while checking arguments for embedding)

# %%
for token, score in zip(tokens, attributions.detach().cpu().numpy()):
    print(f"{token:15} --> {score:.4f}")
